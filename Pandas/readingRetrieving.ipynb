# %%
import pandas as pd 
import numpy as np

# %%
pd.DataFrame.from_dict(dict([('A',[1,2,3]),('B',[4,5,6])]),
                       orient = 'index',columns=['one','two','three'])
# Out:
#    one  two  three
# A    1    2      3
# B    4    5      6

# %%
df1 = pd.DataFrame({'A':[1,np.nan,3,np.nan]})
df2 = pd.DataFrame({'A':[8,9,3,5]})
df1.combine_first(df2)
# Out:
#      A
# 0  1.0
# 1  9.0
# 2  3.0
# 3  5.0

# %%
arr1 = np.random.randint(10,50,size = (2,3))
df3 = pd.DataFrame(arr1 , ['A','B'],['C','D','E'])
df3
# Out:
#     C   D   E
# A  24  16  38
# B  14  26  35

# %%
print('Greater than 30 only\n', df3 > 30)
# Out:
# Greater than 30 only
#         C      D     E
# A  False  False  True
# B  False  False  True

# %%
bool1 = df3 > 25
df3[bool1]
# Out:
#     C     D   E
# A NaN   NaN  38
# B NaN  26.0  35

# %%
df4 = df3[df3['E'] > 30 ]
df4
# Out:
#     C   D   E
# A  24  16  38
# B  14  26  35

# %%
df4['E']
# Out:
# A    38
# B    35
# Name: E, dtype: int32

# %% [markdown]
# Importing data files

# %%
import pymysql 
import numpy as np 
import pandas as pd
cs_df = pd.read_csv('computerSales.csv') 

cs_df
# Out:
#     Unnamed: 0  Sale ID          Contact Sex  Age State Product ID  \
# 0            0        1      Paul Thomas   M   43    OH  M01-F0024
# 1            1        2      Margo Simms   F   37    WV  GT13-0024
# 2            2        3        Sam Stine   M   26    PA      I3670
# 3            3        4       Moe Eggert   M   35    PA      I3593
# 4            4        5      Jessica Elk   F   55    PA     15M-ED
# 5            5        6  Sally Struthers   F   45    PA  GT13-0024
# 6            6        7   Michelle Samms   F   46    OH    GA401IV
# 7            7        8     Mick Roberts   M   23    OH    MY2J2LL
# 8            8        9      Ed Klondike   M   52    OH     81TC00
# 9            9       10       Phil Jones   M   56    WV  M01-F0024
# 10          10       11       Rick James   M   49    PA    GA401IV
# 11          11       12         Sue Etna   F   54    OH  GT13-0024
# 12          12       13       Jason Case   M   57    PA     81TC00
# ...

# %%
import pandas as pd
cs_df.to_csv('computerSales.csv')
# pd.read_excel('Financial Sample.xlsx',0)
pd.read_excel('Financial Sample.xlsx',0)
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera          None
# 1          Government                   Germany  Carretera          None
# 2           Midmarket                    France  Carretera          None
# 3           Midmarket                   Germany  Carretera          None
# 4           Midmarket                    Mexico  Carretera          None
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
cs_df1 = pd.read_csv('icecreamsales.csv') 
cs_df1
# Out:
#     Temperature  Sales
# 0            37    292
# 1            40    228
# 2            49    324
# 3            61    376
# 4            72    440
# 5            79    496
# 6            83    536
# 7            81    556
# 8            75    496
# 9            64    412
# 10           53    324
# 11           40    320

# %%
cs_df.to_excel('ComputerSales.xlsx')
pd.read_excel('ComputerSales.xlsx')
# Out:
#     Unnamed: 0.1  Unnamed: 0  Sale ID          Contact Sex  Age State  \
# 0              0           0        1      Paul Thomas   M   43    OH
# 1              1           1        2      Margo Simms   F   37    WV
# 2              2           2        3        Sam Stine   M   26    PA
# 3              3           3        4       Moe Eggert   M   35    PA
# 4              4           4        5      Jessica Elk   F   55    PA
# 5              5           5        6  Sally Struthers   F   45    PA
# 6              6           6        7   Michelle Samms   F   46    OH
# 7              7           7        8     Mick Roberts   M   23    OH
# 8              8           8        9      Ed Klondike   M   52    OH
# 9              9           9       10       Phil Jones   M   56    WV
# 10            10          10       11       Rick James   M   49    PA
# 11            11          11       12         Sue Etna   F   54    OH
# ...

# %%
try:
  db_connect = pymysql.connect(db='students',user='studentAdmin',passwd='1234!@#$',host='localhost',port=3306)
  
  stud_df = pd.read_sql('SELECT * FROM students ',con=db_connect)
  print(stud_df)
except Exception as e :
  print('Exception : {}', format(e))
finally:
  db_connect.close()
# Out:
# Exception : {} (1045, "Access denied for user 'studentAdmin'@'localhost' (using password: YES)")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# g:\JAVASCRIPT\pythonFramworks\Pandas\readingRetrieving.ipynb Cell 14' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/g%3A/JAVASCRIPT/pythonFramworks/Pandas/readingRetrieving.ipynb#ch0000017?line=6'>7</a>   print('Exception : {}', format(e))
#       <a href='vscode-notebook-cell:/g%3A/JAVASCRIPT/pythonFramworks/Pandas/readingRetrieving.ipynb#ch0000017?line=7'>8</a> finally:
# ----> <a href='vscode-notebook-cell:/g%3A/JAVASCRIPT/pythonFramworks/Pandas/readingRetrieving.ipynb#ch0000017?line=8'>9</a>   db_connect.close()
#
# NameError: name 'db_connect' is not defined
